# %%
import cv2

# %%
img = cv2.imread('/home/amal/Documents/Data-Science-ML-AI_Big_Data_with_Cloud_TABLEAU/Deep Learning/OpenCV/data/faces/1.jpeg')

# %%
print(img)
# Out:
# [[[195 195 201]
#   [195 195 201]
#   [195 195 201]
#   ...
#   [206 207 211]
#   [206 207 211]
#   [206 207 211]]
#
#  [[195 195 201]
#   [195 195 201]
#   [195 195 201]
#   ...
#   [206 207 211]
#   [206 207 211]
#   [206 207 211]]
#
#  [[195 195 201]
#   [195 195 201]
#   [195 195 201]
#   ...
#   [206 207 211]
#   [206 207 211]
#   [206 207 211]]
#
#  ...
#
#  [[ 87 110 156]
#   [ 81 103 145]
#   [ 70  88 125]
#   ...
#   [ 74 100 140]
#   [ 87 113 153]
#   [ 78 104 144]]
#
#  [[ 56  85 129]
#   [ 71  97 137]
#   [ 79 100 131]
#   ...
#   [ 81 107 144]
#   [ 77 103 140]
#   [ 87 113 150]]
#
#  [[ 63  95 136]
#   [ 67  96 133]
#   [ 69  91 119]
#   ...
#   [ 81 107 144]
#   [ 77 103 140]
#   [ 87 113 150]]]

# %% [markdown]
# Here the metrices are pixel values in RGB format

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)

# %% [markdown]
# The image is shown as BGR(Blue, Green, Red) format

# %%
cv2.imshow('image',img)
cv2.waitKey(5000) # howmuch time we can see
cv2.destroyAllWindows()

# %% [markdown]
# To see in original form(converted image)

# %%
converted_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(converted_img)

# %%
gray_img = cv2.imread('/home/amal/Documents/Data-Science-ML-AI_Big_Data_with_Cloud_TABLEAU/Deep Learning/OpenCV/data/faces/1.jpeg',cv2.IMREAD_GRAYSCALE)

# %%
cv2.imshow('image',gray_img)
cv2.waitKey(10000) # howmuch time we can see
cv2.destroyAllWindows()

# %%
grey_img_converted = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2.imshow('@@@@@gray image converted',grey_img_converted)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
cv2.imshow('gray img converted', grey_img_converted)
cv2.imshow('image', gray_img)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (274, 184, 3)

# %% [markdown]
# here 3 means RGB
# (hight, width, channel)

# %%
gray_img.shape
# Out:
# (274, 184)

# %% [markdown]
# To save processed image

# %%
cv2.imwrite('/home/amal/Documents/Data-Science-ML-AI_Big_Data_with_Cloud_TABLEAU/Deep Learning/OpenCV/data/faces/converted_img.jpg', grey_img_converted)
# Out:
# True

# %% [markdown]
# Binary image / balck and white image

# %%
(thresh,img_bw) = cv2.threshold(grey_img_converted, 50, 255, cv2.THRESH_BINARY)
#128 is threshold value, 255 is maximum value

# %%
print(thresh)
# Out:
# 50.0

# %%
cv2.imshow('binary image', img_bw)
cv2.waitKey(5000)
cv2.destroyAllWindows()

# %%
(thresh,img_bw) = cv2.threshold(grey_img_converted, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
#128 is threshold value, 255 is maximum value

# %% [markdown]
# so we don't have to apply threshold manually

# %%
cv2.imshow('binary image', img_bw)
cv2.waitKey(5000)
cv2.destroyAllWindows()
