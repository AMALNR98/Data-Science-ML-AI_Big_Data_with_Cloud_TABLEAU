# %%
import numpy as np
import pandas as pd
iris_flower_data = pd.read_csv('/content/Iris.csv')
iris_flower_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# Here we don't need Id for training, so drop id coulumn

# %%
iris = iris_flower_data.drop(['Id'], axis = 1)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.isna().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# Set input to x and output to y, and set it as an array(for that add '.values') output always should be 1 dimensional

# %%
x = iris.iloc[:, :-1].values
y = iris.iloc[:, -1].values
x.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %% [markdown]
# Set training and testin data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30)

# %%
x_train
# Out:
# array([[6.1, 2.9, 4.7, 1.4],
#        [6.4, 2.7, 5.3, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.8, 2.7, 4.1, 1. ],
#        [7. , 3.2, 4.7, 1.4],
#        [4.9, 3. , 1.4, 0.2],
#        [6.4, 3.1, 5.5, 1.8],
#        [6.3, 3.3, 4.7, 1.6],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.5, 3. , 5.5, 1.8],
#        [5.1, 3.7, 1.5, 0.4],
#        [5. , 3.5, 1.6, 0.6],
#        [4.4, 3.2, 1.3, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [6.6, 2.9, 4.6, 1.3],
#        [6.7, 3.3, 5.7, 2.1],
#        [4.6, 3.4, 1.4, 0.3],
#        [7.6, 3. , 6.6, 2.1],
#        [6.1, 2.6, 5.6, 1.4],
#        [6.1, 3. , 4.6, 1.4],
#        [5. , 3.6, 1.4, 0.2],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.3, 3.7, 1.5, 0.2],
#        [5.1, 3.5, 1.4, 0.2],
#        [5.8, 2.6, 4. , 1.2],
#        [6.7, 3.3, 5.7, 2.5],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.7, 2.5, 5. , 2. ],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3. , 5.2, 2.3],
# ...

# %%
y_train
# Out:
# array(['Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-virginica', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica',
# ...

# %%
x_test
# Out:
# array([[6.4, 2.8, 5.6, 2.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.4, 3.2, 4.5, 1.5],
#        [5. , 3.5, 1.3, 0.3],
#        [5.6, 2.5, 3.9, 1.1],
#        [6.3, 3.3, 6. , 2.5],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.4, 2.8, 5.6, 2.2],
#        [5.6, 2.7, 4.2, 1.3],
#        [6.3, 2.7, 4.9, 1.8],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 2.5, 3. , 1.1],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.5, 3.5, 1.3, 0.2],
#        [5.5, 2.3, 4. , 1.3],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.8, 4. , 1.2, 0.2],
#        [5.9, 3. , 4.2, 1.5],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.5, 2.8, 4.6, 1.5],
#        [5. , 3.4, 1.6, 0.4],
#        [6.7, 3.1, 5.6, 2.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.1, 3.8, 1.9, 0.4],
#        [6.5, 3.2, 5.1, 2. ],
#        [4.8, 3. , 1.4, 0.1],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.7, 3. , 4.2, 1.2],
# ...

# %%
y_test
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica'],
#       dtype=object)

# %% [markdown]
# Normalization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
normalized_x_train_data = scaler.transform(x_train)
normalized_x_test_data = scaler.transform(x_test)

# %%
normalized_x_train_data
# Out:
# array([[ 0.28378489, -0.38183796,  0.53004943,  0.27532185],
#        [ 0.63572284, -0.84267687,  0.86364698,  0.92060742],
#        [ 1.4569114 , -0.1514185 ,  1.19724452,  1.17872166],
#        [-1.71053018, -0.1514185 , -1.36033665, -1.27336354],
#        [-0.06815306, -0.84267687,  0.19645189, -0.24090662],
#        [ 1.33959875,  0.30942041,  0.53004943,  0.27532185],
#        [-1.12396692, -0.1514185 , -1.30473706, -1.27336354],
#        [ 0.63572284,  0.07900096,  0.97484616,  0.79155031],
#        [ 0.51841019,  0.53983987,  0.53004943,  0.53343608],
#        [ 0.51841019,  0.77025933,  1.03044575,  1.565893  ],
#        [ 0.75303549, -0.1514185 ,  0.97484616,  0.79155031],
#        [-0.88934162,  1.4615177 , -1.24913747, -1.01524931],
#        [-1.00665427,  1.00067878, -1.19353788, -0.75713508],
#        [-1.71053018,  0.30942041, -1.36033665, -1.27336354],
#        [-1.35859222,  0.30942041, -1.36033665, -1.27336354],
# ...

# %%
normalized_x_test_data
# Out:
# array([[ 0.63572284, -0.61225741,  1.03044575,  1.17872166],
#        [-0.18546571, -0.61225741,  0.19645189,  0.14626473],
#        [ 0.63572284,  0.30942041,  0.41885025,  0.40437896],
#        [-1.00665427,  1.00067878, -1.36033665, -1.14430643],
#        [-0.30277837, -1.30351578,  0.08525271, -0.1118495 ],
#        [ 0.51841019,  0.53983987,  1.25284411,  1.69495012],
#        [ 0.51841019, -1.30351578,  0.64124861,  0.40437896],
#        [ 0.63572284, -0.61225741,  1.03044575,  1.30777877],
#        [-0.30277837, -0.84267687,  0.25205148,  0.14626473],
#        [ 0.51841019, -0.84267687,  0.64124861,  0.79155031],
#        [-0.53740367,  1.92235661, -1.36033665, -1.01524931],
#        [-0.88934162, -1.30351578, -0.41514361, -0.1118495 ],
#        [ 0.9876608 ,  0.07900096,  0.36325066,  0.27532185],
#        [-0.42009102,  1.00067878, -1.36033665, -1.27336354],
#        [-0.42009102, -1.7643547 ,  0.1408523 ,  0.14626473],
# ...

# %% [markdown]
# for create model
#   - create object
#   - assign value for k as 7
#   - To create model fit training data
#   - here u_predic is to check if the machine is trained or not

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(normalized_x_train_data, y_train)
y_pred = knn.predict(normalized_x_test_data)
y_pred
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica'],
#       dtype=object)

# %%
y_test
# Out:
# array(['Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-virginica'],
#       dtype=object)

# %% [markdown]
# Creating confusion matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
matrix_con = confusion_matrix(y_test, y_pred)
matrix_con
# Out:
# array([[13,  0,  0],
#        [ 0, 18,  1],
#        [ 0,  0, 13]])

# %% [markdown]
# Here we have 3 output options so the confusion matrix will be 3*3 matrix

# %% [markdown]
# Calcuate accuracy score

# %%
score = accuracy_score(y_test, y_pred)
score
# Out:
# 0.9777777777777777

# %% [markdown]
# Prediction

# %%
print(knn.predict([[4.7, 4.6, 1.4, 0.3]]))
# Out:
# ['Iris-virginica']

# %% [markdown]
# To plot confusion matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
lables =  ['Iris-virginica', 'Iris-versicolor', 'Iris-setosa']
# The order must be in y_test
cmd = ConfusionMatrixDisplay(matrix_con, display_labels = lables)
cmd.plot()
