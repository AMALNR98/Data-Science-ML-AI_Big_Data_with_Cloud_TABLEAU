# %% [markdown]
# Multiple number of indipendent variables and one dependent variable

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
advertising = pd.read_csv('/content/advertising.csv')
advertising
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
advertising.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
advertising.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
advertising.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
x = advertising.iloc[:,:-1].values
y = advertising.iloc[:,-1].values
x
# Out:
# array([[230.1,  37.8,  69.2],
#        [ 44.5,  39.3,  45.1],
#        [ 17.2,  45.9,  69.3],
#        [151.5,  41.3,  58.5],
#        [180.8,  10.8,  58.4],
#        [  8.7,  48.9,  75. ],
#        [ 57.5,  32.8,  23.5],
#        [120.2,  19.6,  11.6],
#        [  8.6,   2.1,   1. ],
#        [199.8,   2.6,  21.2],
#        [ 66.1,   5.8,  24.2],
#        [214.7,  24. ,   4. ],
#        [ 23.8,  35.1,  65.9],
#        [ 97.5,   7.6,   7.2],
#        [204.1,  32.9,  46. ],
#        [195.4,  47.7,  52.9],
#        [ 67.8,  36.6, 114. ],
#        [281.4,  39.6,  55.8],
#        [ 69.2,  20.5,  18.3],
#        [147.3,  23.9,  19.1],
#        [218.4,  27.7,  53.4],
#        [237.4,   5.1,  23.5],
#        [ 13.2,  15.9,  49.6],
#        [228.3,  16.9,  26.2],
#        [ 62.3,  12.6,  18.3],
#        [262.9,   3.5,  19.5],
#        [142.9,  29.3,  12.6],
#        [240.1,  16.7,  22.9],
#        [248.8,  27.1,  22.9],
#        [ 70.6,  16. ,  40.8],
#        [292.9,  28.3,  43.2],
# ...

# %% [markdown]
# plot graph : we use seaborn
# - in seaborn we can plot scaterplot and prediction line at a time

# %%
#TV vs Sales
import seaborn as sns
sns.regplot(x = advertising['TV'], y = advertising['Sales'], color = 'red')
#or
#sns.regplot(x = advertising['TV'], y = y)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
# Radio vs Sales
sns.regplot(x = advertising['Radio'], y = advertising['Sales'], color = 'blue')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
# News paper vs Sales
sns.regplot(x = advertising['Newspaper'], y = advertising['Sales'], color = 'yellow')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %% [markdown]
# Training And Testing Data

# %%
from pandas.core.common import random_state
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 42)

# %%
x_train
# Out:
# array([[284.3,  10.6,   6.4],
#        [184.9,  21. ,  22. ],
#        [112.9,  17.4,  38.6],
#        [ 23.8,  35.1,  65.9],
#        [290.7,   4.1,   8.5],
#        [ 19.4,  16. ,  22.3],
#        [293.6,  27.7,   1.8],
#        [ 18.7,  12.1,  23.4],
#        [134.3,   4.9,   9.3],
#        [ 25.6,  39. ,   9.3],
#        [100.4,   9.6,   3.6],
#        [ 80.2,   0. ,   9.2],
#        [188.4,  18.1,  25.6],
#        [177. ,  33.4,  38.7],
#        [125.7,  36.9,  79.2],
#        [209.6,  20.6,  10.7],
#        [142.9,  29.3,  12.6],
#        [184.9,  43.9,   1.7],
#        [222.4,   4.3,  49.8],
#        [241.7,  38. ,  23.2],
#        [ 17.2,  45.9,  69.3],
#        [120.5,  28.5,  14.2],
#        [ 89.7,   9.9,  35.7],
#        [191.1,  28.7,  18.2],
#        [ 75.5,  10.8,   6. ],
#        [193.2,  18.4,  65.7],
#        [ 85.7,  35.8,  49.3],
#        [266.9,  43.8,   5. ],
#        [ 39.5,  41.1,   5.8],
#        [261.3,  42.7,  54.7],
#        [ 13.2,  15.9,  49.6],
# ...

# %%
x_test
# Out:
# array([[163.3,  31.6,  52.9],
#        [195.4,  47.7,  52.9],
#        [292.9,  28.3,  43.2],
#        [ 11.7,  36.9,  45.2],
#        [220.3,  49. ,   3.2],
#        [ 75.1,  35. ,  52.7],
#        [216.8,  43.9,  27.2],
#        [ 50. ,  11.6,  18.4],
#        [222.4,   3.4,  13.1],
#        [175.1,  22.5,  31.5],
#        [ 31.5,  24.6,   2.2],
#        [ 56.2,   5.7,  29.7],
#        [234.5,   3.4,  84.8],
#        [  5.4,  29.9,   9.4],
#        [139.5,   2.1,  26.6],
#        [170.2,   7.8,  35.2],
#        [  7.3,  28.1,  41.4],
#        [197.6,  23.3,  14.2],
#        [ 75.3,  20.3,  32.5],
#        [237.4,  27.5,  11. ],
#        [229.5,  32.3,  74.2],
#        [ 67.8,  36.6, 114. ],
#        [ 38. ,  40.3,  11.9],
#        [250.9,  36.5,  72.3],
#        [ 69. ,   9.3,   0.9],
#        [ 53.5,   2. ,  21.4],
#        [213.5,  43. ,  33.8],
#        [139.3,  14.5,  10.2],
#        [ 87.2,  11.8,  25.9],
#        [  8.4,  27.2,   2.1],
#        [199.8,   2.6,  21.2],
# ...

# %%
y_train
# Out:
# array([20. , 20.5, 11.9,  9.2, 17.8,  6.6, 20.7,  6.7, 14. ,  9.5, 10.7,
#        11.9, 19.9, 17.1, 15.9, 20.9, 15. , 20.7, 16.7, 21.8, 12. , 14.2,
#        10.6, 17.3, 11.9, 20.2, 13.3, 25.4, 10.8, 24.2,  5.6, 19.2, 23.8,
#        17.4, 17.4, 17.3, 12.9, 11.8, 20.9, 15.5, 17.9, 13.2, 20.1, 10.3,
#        19.8, 12.3, 12.6, 20.7, 17.1, 18.2,  8. , 22.1, 25.5, 16. , 18.3,
#        15.2, 16. ,  8.5, 18. , 18.9, 16.6,  5.3,  3.2, 15.3, 17. , 20.5,
#        17.6, 25.4, 17.3, 21.5, 17.1, 23.2, 11.5, 20.6, 17.9,  9.6, 16.5,
#        15. , 21.2, 19.6, 15.5, 16.8, 22.6,  9.7, 11.8, 11.9, 13.2, 18.4,
#         7.3, 13.6, 20.2, 17.2, 16.7,  4.8, 13.7, 18.4, 17.5, 17.7, 24.4,
#         8.8, 27. , 10.8, 17.2, 26.2, 14. , 20.2, 12. , 16.4, 14. , 23.8,
#        19.8, 12.9, 17.5, 13.2, 16.4,  5.9,  9.7, 14.7, 10.1, 19.6, 10.4,
#        22.6, 10.1,  1.6, 11.6, 19.7, 17.2, 12.2, 16. , 17. ,  7. , 18.4,
#        18. , 20.9, 12.4,  7.2, 19. , 19.4, 17.6, 19.8])

# %%
y_test
# Out:
# array([16.9, 22.4, 21.4,  7.3, 24.7, 12.6, 22.3,  8.4, 16.5, 16.1, 11. ,
#         8.7, 16.9,  5.3, 10.3, 16.7,  5.5, 16.6, 11.3, 18.9, 19.7, 12.5,
#        10.9, 22.2, 11.3,  8.1, 21.7, 13.4, 10.6,  5.7, 15.6, 11.3, 23.7,
#         8.7, 16.1, 20.7, 11.6, 20.8, 11.9,  6.9, 11. , 14.8, 10.1,  9.7,
#        16.6,  7.6, 10.5, 14.6, 10.4, 12. , 14.6, 16.7,  7.2,  6.6,  9.4,
#        11. , 10.9, 25.4,  7.6, 16.7])

# %%
from sklearn.linear_model import LinearRegression
# Create Object(model)
model = LinearRegression()
# fit model
model.fit(x_train, y_train)
# Predict value
y_pred = model.predict(x_test)
y_pred
# Out:
# array([17.15991908, 20.53369503, 23.68914396,  9.5191455 , 21.60736836,
#        12.78101318, 21.08636345,  8.76054246, 17.11499951, 16.68789636,
#         8.97584663,  8.57645026, 18.33212325,  8.17863567, 12.64605571,
#        14.94486946,  8.34939536, 17.83858948, 11.12172174, 20.37740648,
#        20.9483297 , 13.04035779, 11.01360656, 22.51142595,  9.40369784,
#         7.98591291, 20.86943368, 13.77882255, 10.83407064,  8.00419229,
#        15.88597618, 10.7027424 , 20.9521718 , 10.84679243, 21.50720813,
#        21.07347295, 12.22673775, 22.85273767, 12.57698182,  6.54597206,
#        11.93411853, 15.23490068, 10.07411153,  9.52159696, 17.11786382,
#         7.28032677, 10.49404864, 15.24356754, 11.20742176, 11.78392665,
#        14.01472163, 14.59884572, 10.82722434,  9.55839415,  9.03749681,
#        12.51183313, 10.52551021, 25.01900824,  7.99334943, 15.73916263])

# %% [markdown]
# prediction

# %%
print(model.predict([[150.1, 45.5, 75.4]]))
# Out:
# [18.05863495]

# %% [markdown]
# Data Frame

# %%
df = pd.DataFrame({'Actual_value':y_test, 'Predicted_value':y_pred, 'Difference': y_test - y_pred})
df
# Out:
#     Actual_value  Predicted_value  Difference
# 0           16.9        17.159919   -0.259919
# 1           22.4        20.533695    1.866305
# 2           21.4        23.689144   -2.289144
# 3            7.3         9.519146   -2.219146
# 4           24.7        21.607368    3.092632
# 5           12.6        12.781013   -0.181013
# 6           22.3        21.086363    1.213637
# 7            8.4         8.760542   -0.360542
# 8           16.5        17.115000   -0.615000
# 9           16.1        16.687896   -0.587896
# 10          11.0         8.975847    2.024153
# 11           8.7         8.576450    0.123550
# 12          16.9        18.332123   -1.432123
# 13           5.3         8.178636   -2.878636
# 14          10.3        12.646056   -2.346056
# 15          16.7        14.944869    1.755131
# 16           5.5         8.349395   -2.849395
# 17          16.6        17.838589   -1.238589
# 18          11.3        11.121722    0.178278
# ...

# %% [markdown]
# Print slope

# %%
print('slope is', model.coef_) #TV. Radio, NewsPaper
# Out:
# slope is [0.05358869 0.10270677 0.00793167]

# %%
# To print seperatly
print('slop of TV is :', model.coef_[0])
print('slop of Radio is :', model.coef_[1])
print('slop of NewsPaper is :', model.coef_[2])
# Out:
# slop of TV is : 0.05358869132706914
# slop of Radio is : 0.10270676778771294
# slop of NewsPaper is : 0.007931667677316338

# %% [markdown]
# Or using zip

# %%
print("Slope is")
list(zip(x, model.coef_))
# Out:
# Slope is
# [(array([230.1,  37.8,  69.2]), 0.05358869132706914),
#  (array([44.5, 39.3, 45.1]), 0.10270676778771294),
#  (array([17.2, 45.9, 69.3]), 0.007931667677316338)]

# %% [markdown]
# Pring constant

# %%
print("constant is ", model.intercept_)
# Out:
# constant is  4.743766701589685

# %% [markdown]
# Perfomance Evaluation

# %%
# Mean Absoulte Percentage error
from sklearn.metrics import mean_absolute_percentage_error
print("Error percentage is ", mean_absolute_percentage_error(y_test, y_pred))
# Out:
# Error percentage is  0.10536440823029315

# %%
# R2_Score
from sklearn.metrics import r2_score
print("R2 score is", r2_score(y_test, y_pred))
# Out:
# R2 score is 0.9091484341849799
